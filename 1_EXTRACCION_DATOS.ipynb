# %%
#Instalas librerias
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# Out:
# Requirement already satisfied: numpy in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jasiel\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\jasiel\appdata\local\programs\python\python312\lib\site-packages (24.0)
# Collecting pip
#   Downloading pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 991.0 kB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.8 MB 880.9 kB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.8 MB 1.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.8 MB 1.6 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/1.8 MB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-24.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx')
df
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 0          6401                               DONGA HWASUNG MEXICO   F40238
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3          3930                               INDUSTRIAS LANCERMEX   F40217
# 4          4712                                             HELVEX   F40173
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0      2023-02-24        2023-03-26        97485.94
# 1      2023-03-14        2023-04-13        97485.94
# 2      2023-03-14        2023-04-13        64916.21
# 3      2023-02-23        2023-03-25        52715.74
# 4      2023-02-17        2023-04-03        50639.80
# ..            ...               ...             ...
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94
#
# [164 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. CLIENTE        164 non-null    object
#  1   NOMBRE             164 non-null    object
#  2   FACTURA            164 non-null    object
#  3   FECHA_FACTURA      164 non-null    datetime64[ns]
#  4   FECHA_VENCIMIENTO  164 non-null    datetime64[ns]
#  5   MONTO ADEUDADO     164 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 7.8+ KB

# %%
df.head()
# Out:
#   No. CLIENTE                                        NOMBRE FACTURA  \
# 0        6401                          DONGA HWASUNG MEXICO  F40238
# 1        6401                          DONGA HWASUNG MEXICO  F40353
# 2        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO  F40352
# 3        3930                          INDUSTRIAS LANCERMEX  F40217
# 4        4712                                        HELVEX  F40173
#
#   FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0    2023-02-24        2023-03-26        97485.94
# 1    2023-03-14        2023-04-13        97485.94
# 2    2023-03-14        2023-04-13        64916.21
# 3    2023-02-23        2023-03-25        52715.74
# 4    2023-02-17        2023-04-03        50639.80

# %%
#Filtro por objeto
filtro1 = df[df["NOMBRE"]== "INDUSTRIAS LANCERMEX"]
filtro1
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 3         3930  INDUSTRIAS LANCERMEX  F40217    2023-02-23        2023-03-25
# 12        3930  INDUSTRIAS LANCERMEX  F40114    2023-02-09        2023-03-11
#
#     MONTO ADEUDADO
# 3         52715.74
# 12        35143.82

# %%
#Filtro por filas
#filtro2 = df.iloc[3:10, :]           #Filas consecutivas
filtro2 = df.iloc[[8,24,100], : ]     #Filas no consecutivas
filtro2
# Out:
#     No. CLIENTE                  NOMBRE FACTURA FECHA_FACTURA  \
# 8           644   CLAVOS NACIONALES C.N  F40340    2023-03-13
# 24         8708       TE.MEX AUTOMOTIVE  F40183    2023-02-20
# 100        3926  PRODUCTOS PENNSYLVANIA  F40357    2023-03-14
#
#     FECHA_VENCIMIENTO  MONTO ADEUDADO
# 8          2023-05-12        45216.34
# 24         2023-03-13        22956.40
# 100        2023-04-13         2756.16

# %%
#filtro por columnas
filtro3 = df.iloc[:, 1:3]    #Columnas consecutivas
#filtro3 = df.iloc[:, [1,4,5]] #Columnas no consecutivas
filtro3
# Out:
#                                                 NOMBRE  FACTURA
# 0                                 DONGA HWASUNG MEXICO   F40238
# 1                                 DONGA HWASUNG MEXICO   F40353
# 2         PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 3                                 INDUSTRIAS LANCERMEX   F40217
# 4                                               HELVEX   F40173
# ..                                                 ...      ...
# 159  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160                                 PÚBLICO EN GENERAL  NV00777
# 161                                 PÚBLICO EN GENERAL  NV00778
# 162                                 PÚBLICO EN GENERAL  NV00779
# 163                                  FISHERS QUERETARO   F38248
#
# [164 rows x 2 columns]

# %%
#Filtro

# %%
df1 = pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx', index_col=1)
df1
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      6401   F40238
# DONGA HWASUNG MEXICO                                      6401   F40353
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              4598   F40352
# INDUSTRIAS LANCERMEX                                      3930   F40217
# HELVEX                                                    4712   F40173
# ...                                                        ...      ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                  2023-02-24
# DONGA HWASUNG MEXICO                                  2023-03-14
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO          2023-03-14
# INDUSTRIAS LANCERMEX                                  2023-02-23
# HELVEX                                                2023-02-17
# ...                                                          ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...    2023-01-31
# PÚBLICO EN GENERAL                                    2023-03-07
# PÚBLICO EN GENERAL                                    2023-03-09
# PÚBLICO EN GENERAL                                    2023-03-09
# FISHERS QUERETARO                                     2022-05-27
#
#                                                    FECHA_VENCIMIENTO  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      2023-03-26
# DONGA HWASUNG MEXICO                                      2023-04-13
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              2023-04-13
# INDUSTRIAS LANCERMEX                                      2023-03-25
# HELVEX                                                    2023-04-03
# ...                                                              ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...        2023-01-31
# PÚBLICO EN GENERAL                                        2023-03-07
# PÚBLICO EN GENERAL                                        2023-03-09
# PÚBLICO EN GENERAL                                        2023-03-09
# FISHERS QUERETARO                                         2022-05-27
#
#                                                     MONTO ADEUDADO
# NOMBRE
# DONGA HWASUNG MEXICO                                      97485.94
# DONGA HWASUNG MEXICO                                      97485.94
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              64916.21
# INDUSTRIAS LANCERMEX                                      52715.74
# HELVEX                                                    50639.80
# ...                                                            ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...           56.00
# PÚBLICO EN GENERAL                                           45.00
# PÚBLICO EN GENERAL                                           40.00
# PÚBLICO EN GENERAL                                           24.01
# FISHERS QUERETARO                                            19.94
#
# [164 rows x 5 columns]

# %%
#Aplicamos filtro de filas vs columnas
filtro4 = df1.loc[["HELVEX", "DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO", "FACTURA"]]
filtro4
# Out:
#                       MONTO ADEUDADO FACTURA
# NOMBRE
# HELVEX                      50639.80  F40173
# DONGA HWASUNG MEXICO        97485.94  F40238
# DONGA HWASUNG MEXICO        97485.94  F40353
# DONGA HWASUNG MEXICO        10759.00  F40320
# DONGA HWASUNG MEXICO         9396.00  F40253

# %%
filtro5 = df.head(10)  #Primeros 10 de la tabla
filtro5
# Out:
#   No. CLIENTE                                        NOMBRE FACTURA  \
# 0        6401                          DONGA HWASUNG MEXICO  F40238
# 1        6401                          DONGA HWASUNG MEXICO  F40353
# 2        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO  F40352
# 3        3930                          INDUSTRIAS LANCERMEX  F40217
# 4        4712                                        HELVEX  F40173
# 5        1429                AUTOLIV STEERING WHEELS MEXICO  F39979
# 6        1429                AUTOLIV STEERING WHEELS MEXICO  F40319
# 7        5039                                      BUSSMANN  F40082
# 8         644                         CLAVOS NACIONALES C.N  F40340
# 9         644                         CLAVOS NACIONALES C.N  F40351
#
#   FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0    2023-02-24        2023-03-26        97485.94
# 1    2023-03-14        2023-04-13        97485.94
# 2    2023-03-14        2023-04-13        64916.21
# 3    2023-02-23        2023-03-25        52715.74
# 4    2023-02-17        2023-04-03        50639.80
# 5    2023-01-24        2023-03-25        49416.00
# 6    2023-03-08        2023-05-07        49416.00
# 7    2023-02-04        2023-02-04        48882.12
# 8    2023-03-13        2023-05-12        45216.34
# 9    2023-03-14        2023-05-13        45216.34

# %%
filtro5 = df.tail(10) #Ultimos 10 de la tabla
filtro5
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 154        5926                                 PÚBLICO EN GENERAL   F35996
# 155        5936                              BURBUPAC DE QUERETARO   F40318
# 156        6048                  AT Y V DESARROLLOS Y MANUFACTURAS   F40370
# 157        5926                                 PÚBLICO EN GENERAL  NV00780
# 158        8698                               OLMO RACKS & DUNNAGE   F38473
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 154    2021-08-31        2021-08-31          200.00
# 155    2023-03-08        2023-04-07          191.04
# 156    2023-03-15        2023-03-15          139.20
# 157    2023-03-13        2023-03-13          130.00
# 158    2022-06-28        2022-06-28           87.35
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94

# %% [markdown]
# ***FILTROS BASICOS PARA VARIABLES CUANTITATIVAS***

# %%
#Filtro por comparación
filtro6=df[df["MONTO ADEUDADO"] > 70000]
filtro6
# Out:
#   No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 0        6401  DONGA HWASUNG MEXICO  F40238    2023-02-24        2023-03-26
# 1        6401  DONGA HWASUNG MEXICO  F40353    2023-03-14        2023-04-13
#
#    MONTO ADEUDADO
# 0        97485.94
# 1        97485.94

# %% [markdown]
# ***FILTROS BASICOS CON CONECTORES LOGICOS***

# %%
#Filtro y
filtro7 = df[(df["MONTO ADEUDADO"]<6000) & (df["FECHA_FACTURA"]=="2023-03-14")]
filtro7
# Out:
#     No. CLIENTE                                             NOMBRE FACTURA  \
# 85          409  CONSTRUCCIONES ELECTROMECANICAS Y SERVICIOS IN...  F40359
# 96         3926                             PRODUCTOS PENNSYLVANIA  F40358
# 100        3926                             PRODUCTOS PENNSYLVANIA  F40357
# 101        5926                                 PÚBLICO EN GENERAL  F40362
# 113        2216                                         FRESCOPACK  F40355
# 132        1284                                      TERMOFORMADOS  F40349
# 135        8872                            GABRIELA GARCIA SANCHEZ  F40360
# 139        8228                                      UCH COMERCIAL  F40365
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 85     2023-03-14        2023-03-14         4292.00
# 96     2023-03-14        2023-04-13         3368.64
# 100    2023-03-14        2023-04-13         2756.16
# 101    2023-03-14        2023-03-14         2694.95
# 113    2023-03-14        2023-03-14         1682.00
# 132    2023-03-14        2023-04-13          799.24
# 135    2023-03-14        2023-03-14          754.00
# 139    2023-03-14        2023-03-14          702.96

# %%
#Filtro o
filtro8 = df[(df["MONTO ADEUDADO"]<6000) | (df["FECHA_FACTURA"]== "2023-03-14")]
filtro8
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 1          6401                               DONGA HWASUNG MEXICO   F40353
# 2          4598       PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   F40352
# 9           644                              CLAVOS NACIONALES C.N   F40351
# 10         3937                                           RICHALUM   F40361
# 36          417                                            COVEMEX   F40354
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 1      2023-03-14        2023-04-13        97485.94
# 2      2023-03-14        2023-04-13        64916.21
# 9      2023-03-14        2023-05-13        45216.34
# 10     2023-03-14        2023-03-14        42880.05
# 36     2023-03-14        2023-03-29        15843.28
# ..            ...               ...             ...
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94
#
# [101 rows x 6 columns]

# %%
#Filtro not
filtro9 = df[~(df["MONTO ADEUDADO"] >= 6000) & ~(df["FECHA_FACTURA"] == "2023-03-14")]
filtro9
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 70         1852                                       ITW POLY MEX   F40201
# 71         8316                          ANA BARBARA CRUZ PALACIOS   F40379
# 72         8787                            ARMANDO VIDAURRETA PEÑA   F39769
# 73         2768                                  CEREALES Y PASTAS   F40215
# 74         1831           DISTRIBUCIONES Y REPRESENTACIONES CALORA   F40316
# ..          ...                                                ...      ...
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 70     2023-02-22        2023-03-24         5967.85
# 71     2023-03-16        2023-03-31         5827.84
# 72     2022-12-14        2022-12-14         5800.00
# 73     2023-02-22        2023-03-24         5660.80
# 74     2023-03-08        2023-04-22         5502.81
# ..            ...               ...             ...
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94
#
# [86 rows x 6 columns]

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")
